# %%
import pandas as pd
import skcriteria as skc
import numpy as np
import matplotlib.pyplot as plt
import json
import yaml
import pprint
from tabulate import tabulate

from skcriteria.preprocessing import invert_objectives, scalers
from skcriteria.madm import simple

def get_id(key):
    criterion_key = {
        'Name' : 'name',
        'Elastic Modulus' : 'elastic_mod',
        'Yield Strength' : 'yield_strength',
        'Cost' : 'cost',
        'Ultimate Strength': 'ult_strength',
        'Machineability' : 'machineability'
    }

    if type(key) == list:
        result = [criterion_key.get(k) for k in key]
        result = [x for x in result if x != None]
        return result

    return criterion_key.get(key)

with open('C:/Users/ttrol/CodingProjects/MatNet/webscraper/results_files/AISI_steels_fakedata.yaml','r') as stream:
    try:
        raw_data = yaml.safe_load(stream)
    except FileNotFoundError:
        raise FileNotFoundError

raw_dataframe = pd.DataFrame(raw_data)

# %%
criterions = ["Elastic Modulus",
                       "Yield Strength", "Cost", "Ultimate Strength", "Machineability"]
raw_weights = [0, 0, 0, 0, -2]

formData = {}
for i in range(5):
    if criterions[i] != '' and raw_weights[i] != 0:
        formData[criterions[i]] = raw_weights[i]  

# print(formData)

weights = np.asarray(list(formData.values()))
weights = np.divide(weights,10)


objectives = []
for weight in weights:
    if weight < 0:
        objectives.append(min)
    elif weight > 0:
        objectives.append(max)


criterion_ids = get_id(list(formData.keys()))

df = raw_dataframe.loc[:, criterion_ids]        #type: ignore
# # let's says the first two alternatives are
# # for maximization and the last one for minimization

# we use the built-in function as aliases
row_id =  list(raw_dataframe.loc[:, 'name'])
dm = skc.mkdm(
    df.to_numpy(),
    objectives= objectives,
    weights= weights,
    alternatives = row_id,
    criteria= list(formData.keys())
)
dm
# Out:
#                                                     Machineability[▼-0.2]
# AISI E9310H Steel, normalized, machined to 25 m...                     49
# AISI 4027 Steel, normalized, 14 mm (0.55 in.) r...                      2
# AISI 1020 Steel, mock carburized at 915°C (1680...                     36
# AISI 1095 Steel, oil quenched 800°C (1470°F), 4...                     14
# AISI 4620H Steel, direct quench from pot, carbu...                     71
# ...                                                                   ...
# AISI 1060 Steel, oil quenched 845°C (1550°F), 4...                     57
# AISI Grade 18Ni (250) Maraging Steel, 3.18 mm t...                     80
# AISI 1340H Steel, oil quenched from 830°C (1525...                     11
# AISI 4820 Steel, mock carburized, reheated to 8...                     57
# AISI 4815H Steel, pseudocarburized and oil quen...                     57
# [1813 Alternatives x 1 Criteria]

# %%
from skcriteria.preprocessing import invert_objectives, scalers
from skcriteria.madm import simple

#SKC handles maximization or minimization only best , so we invert the third row to be a maximization problem 
#maximization is preferable to minimizationm
inverter = invert_objectives.InvertMinimize()
dmt = inverter.transform(dm)

#normalizes values
scaler = scalers.SumScaler(target="both")
dmt = scaler.transform(dmt)

dec = simple.WeightedSumModel()
dec

rank = dec.evaluate(dmt)  # we use the tansformed version of the data

rank
# Out:
# c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\preprocessing\invert_objectives.py:127: RuntimeWarning: divide by zero encountered in divide
#   inverted_values = 1.0 / inv_mtx[:, minimize_mask]
# c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\preprocessing\scalers.py:372: RuntimeWarning: invalid value encountered in divide
#   return arr / sumval
# c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\utils\rank.py:67: RuntimeWarning: invalid value encountered in cast
#   return stats.rankdata(arr, "dense").astype(int)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 15
#      13 dec = simple.WeightedSumModel()
#      14 dec
# ---> 15 rank = dec.evaluate(dmt)  # we use the tansformed version of the data
#      16 rank
#
# File c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\madm\_madm_base.py:67, in SKCDecisionMakerABC.evaluate(self, dm)
#      64 result_data, extra = self._evaluate_data(**data)
#      66 alternatives = data["alternatives"]
# ---> 67 result = self._make_result(
#      68     alternatives=alternatives, values=result_data, extra=extra
#      69 )
#      71 return result
#
# File c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\madm\simple.py:97, in WeightedSumModel._make_result(self, alternatives, values, extra)
#      94 @doc_inherit(SKCDecisionMakerABC._make_result)
#      95 def _make_result(self, alternatives, values, extra):
# ---> 97     return RankResult(
#      98         "WeightedSumModel",
#      99         alternatives=alternatives,
#     100         values=values,
#     101         extra=extra,
#     102     )
#
# File c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\madm\_madm_base.py:109, in ResultABC.__init__(self, method, alternatives, values, extra)
#     108 def __init__(self, method, alternatives, values, extra):
# --> 109     self._validate_result(values)
#     110     self._method = str(method)
#     111     self._extra = Bunch("extra", extra)
#
# File c:\Users\ttrol\CodingProjects\MatNet\.conda\lib\site-packages\skcriteria\madm\_madm_base.py:350, in RankResult._validate_result(self, values)
#     348 expected = np.arange(length) + 1
#     349 if not np.array_equal(np.sort(cleaned_values), expected):
# --> 350     raise ValueError(f"The data {values} doesn't look like a ranking")
#
# ValueError: The data [-2147483648 -2147483648 -2147483648 ... -2147483648 -2147483648
#  -2147483648] doesn't look like a ranking

# %%
print(rank.e_.score)
print(rank.rank_)

df_with_score = raw_dataframe.assign(Score = rank.e_.score).assign(Rank = rank.rank_)
SortedDF = df_with_score.sort_values(by = 'Score', ascending = False)
SortedDF
# Out:
# [0.00036493 0.00067371 0.00089187 ... 0.00058233 0.0003041  0.00037428]
# [239  97  43 ... 146 260 236]
#       cost  elastic_mod                                               link  \
# 1072  0.98          206  https://matweb.com/search/DataSheet.aspx?MatGU...
# 1266  7.76          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 11    0.84          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 1230  1.00          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 817   2.01          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# ...    ...          ...                                                ...
# 1138  9.77          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 1046  4.04          203  https://matweb.com/search/DataSheet.aspx?MatGU...
# 49    5.54          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 809   7.47          200  https://matweb.com/search/DataSheet.aspx?MatGU...
# 568   0.26          200  https://matweb.com/search/DataSheet.aspx?MatGU...
#
#       machineability                                               name  \
# 1072              74  AISI 1006 Steel, hot rolled bar, 19-32 mm (0.7...
# 1266               8  AISI 1008 Steel, hot rolled bar, 19-32 mm (0.7...
# 11                11  AISI 1010 Steel, hot rolled bar, 19-32 mm (0.7...
# 1230             100  AISI 1012 Steel, hot rolled bar, 19-32 mm (0.7...
# 817               96  AISI 1008 Steel, CQ, DQ, and DQSK sheet, 1.6-5...
# ...              ...                                                ...
# 1138              23  AISI Grade 18Ni (350) Maraging Steel, Aged, at...
# 1046              21  AISI Type A6 Tool Steel, austenitized 830-870°...
# 49                50  AISI Grade 18Ni (350) Maraging Steel, Aged, at...
# 809               81  AISI Grade 18Ni (350) Maraging Steel, Aged, at...
# 568               22  AISI Grade 18Ni (350) Maraging Steel, Aged, at...
#
#       ult_strength  yield_strength     Score  Rank
# 1072           295             165  0.001484     1
# 1266           305             170  0.001436     2
# 11             325             180  0.001347     3
# 1230           330             185  0.001327     4
# 817            330             210  0.001327     4
# ...            ...             ...       ...   ...
# 1138          2360            2320  0.000186   315
# 1046          2380            2100  0.000184   316
# 49            2390            2350  0.000183   317
# 809           2420            2360  0.000181   318
# 568           2450            2400  0.000179   319
#
# [1813 rows x 9 columns]
